# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from pycaret.classification import *
from sklearn.model_selection import RepeatedStratifiedKFold

import wandb

import os
import sys
sys.path.append('..')
from config import CFG
CFG = CFG()
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', CFG.NCOLS)
pd.set_option('display.max_rows', CFG.NROWS)

# %%
train = pd.read_csv(os.path.join(CFG.RAW_DATA, 'train.csv')).drop(columns='id')
test = pd.read_csv(os.path.join(CFG.RAW_DATA, 'test.csv')).drop(columns='id')

# %%
exp_name = setup(
    data=train, target='Class', polynomial_features=True, fold_strategy=RepeatedStratifiedKFold(), 
    fold=5, log_experiment=True, log_plots=True, log_profile=True, log_data=True,
)

# %%
exp_name = setup(
    data=train, target='Class', polynomial_features=True, fold_strategy=RepeatedStratifiedKFold(), 
    fold=5, #log_experiment=True, log_plots=True, log_profile=True, log_data=True,
)

# %%
exp_name = setup(
    data=train, target='Class', polynomial_features=True, fold_strategy=RepeatedStratifiedKFold(), 
    fold=5, log_experiment=True, log_plots=True,
)

# %%
wandb.init(project='S3E10')

exp_name = setup(
    data=train, target='Class', polynomial_features=True, fold_strategy=RepeatedStratifiedKFold(), 
    fold=5, log_experiment='wandb', log_plots=True,
)
# Out:
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/home/broug/Desktop/S3E10/notebooks/wandb/run-20230313_194335-7lrydl6f</code>
# Syncing run <strong><a href='https://wandb.ai/g-broughton/S3E10/runs/7lrydl6f' target="_blank">peachy-bee-3</a></strong> to <a href='https://wandb.ai/g-broughton/S3E10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/g-broughton/S3E10' target="_blank">https://wandb.ai/g-broughton/S3E10</a>
#  View run at <a href='https://wandb.ai/g-broughton/S3E10/runs/7lrydl6f' target="_blank">https://wandb.ai/g-broughton/S3E10/runs/7lrydl6f</a>
# <style type="text/css">
# #T_81ea6_row8_col1, #T_81ea6_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_81ea6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81ea6_level0_col0" class="col_heading level0 col0" >Description</th>
# ...

# %%
get_metrics()
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc              <function accuracy_score at 0x7f280b7ccf70>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa         <function cohen_kappa_score at 0x7f280b7e10d0>
# mcc           <function matthews_corrcoef at 0x7f280b7e11f0>
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# ...

# %%
from sklearn.metrics import log_loss
add_metric('logloss', 'Log Loss', log_loss, greater_is_better = False)
# Out:
# Name                                                       Log Loss
# Display Name                                               Log Loss
# Score Function                <function log_loss at 0x7f280b7e19d0>
# Scorer               make_scorer(log_loss, greater_is_better=False)
# Target                                                         pred
# Args                                                             {}
# Greater is Better                                             False
# Multiclass                                                     True
# Custom                                                         True
# Name: logloss, dtype: object

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              19:49:00
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, Log Loss, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           19:49:00
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             19:49:00
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             19:49:00
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# ...

# %%
eda()

# %%
from sklearn.metrics import log_loss
add_metric('logloss', 'Log Loss', log_loss)

# %%
remove_metric("logloss")

# %%
from sklearn.metrics import log_loss
add_metric('logloss', 'Log Loss', log_loss)
# Out:
# Name                                              Log Loss
# Display Name                                      Log Loss
# Score Function       <function log_loss at 0x7f280b7e19d0>
# Scorer                               make_scorer(log_loss)
# Target                                                pred
# Args                                                    {}
# Greater is Better                                     True
# Multiclass                                            True
# Custom                                                True
# Name: logloss, dtype: object

# %%
create_model("lgbm")

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
create_model("lightgbm")
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=7645, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              20:50:30
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             20:50:30
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Compiling Library
# ...

# %%
lgbm = create_model("lightgbm")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              20:51:54
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             20:51:54
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .    Compiling Library
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         20:51:54
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# ...

# %%
wandb.init(project='S3E10')

exp_name = setup(
    data=train, target='Class', polynomial_features=True, fold_strategy=RepeatedStratifiedKFold(), 
    fold=5, log_experiment='wandb', log_plots=True, profile=True
)
